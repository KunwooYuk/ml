# %% [markdown]
# ---
# ## 🎁 가산점
#
# ### A. 데이터의 다양성
# - NTP ICE 내 다양한 데이터셋 모두 활용 가능. (https://ice.ntp.niehs.nih.gov/DATASETDESCRIPTION)
# ### B. Feature(descriptor)의 다양성
# - rdkit, VEGA, 등
# ### 💬 추가 설명 (자유 기술)

# %% [markdown]
# # 기말고사 Template 1 — Data Pipeline
#
# **이름:** ______육건우______ &nbsp; **학번:** ______20251284______ &nbsp;
#
# ---
#
# ## 📋 채점 기준 (총 50점)
#
# | 항목 | 배점 | 채점 포인트 |
# |---|---|---|
# | **1. 데이터 분포 파악 및 전처리** | 15점 | 모델 개발 전, 중복 화합물 체크, smiles 코드 정리 등 모델 개발 전 확인해야 할 사항들을 확인. |
# | **2. Descriptor 계산** | 15점 | 모델 개발에 사용할 descriptor의 다양성 |
# | **3. 데이터 시각화 자료** | 15점 | 구조 분포, 라벨 비율 등 데이터 현황을 시각화한 자료 |
# | **4. 코드 가독성 & 주석** | 5점 | 변수의 의미와 코드의 간결성을 평가. |
#
# #### A. 데이터 소스의 다양성
# - NTP ICE에서 구할 수 있는 다양한 데이터
# - NTP ICE 외 추가 데이터 확보
#
# ## 📁 입력 / 출력 예시
# - **입력**: `skin_irritation.xlsx` (NTP ICE) + (선택) 외부 데이터 (데이터가 여러개인 경우 xlsx파일의 zip으로 제출)
# - **출력**: `final_dataset_descriptors.csv`  (Chemical_Name, SMILES, label, 2D descriptor [+ fingerprint 등])

# %%
import numpy as np
import pandas as pd
from rdkit import Chem

# %%
import pandas as pd

file_path = 'cancer.xlsx' 
sheet_all = 'Data'

# pd.read_excel 함수를 사용해 특정 시트 읽기
df = pd.read_excel(file_path, sheet_name=sheet_all)

print("전체 데이터 크기:", df.shape)
print("전체 컬럼 이름:", df.columns)
# Out:
# 전체 데이터 크기: (10351, 28)
# 전체 컬럼 이름: Index(['Record_ID', 'Data_Type', 'Formulation_ID', 'Formulation_Name',
#        'Chemical_Name', 'CASRN', 'DTXSID', 'Percent_Active_Ingredient',
#        'Mixture', 'Species', 'Sex', 'Strain', 'Route', 'Level_of_Evidence',
#        'Tissue', 'Location', 'Lesion', 'Assay', 'Endpoint', 'Response',
#        'Response_Unit', 'Reference', 'URL', 'SMILES', 'Preferred_Name',
#        'Synonyms', 'URL_CompTox', 'URL_CEBS'],
#       dtype='object')

# %%
# 1. smiles 코드가 없는 물질 제거
df_smi = df.dropna(subset=["SMILES"]).copy()
print("SMILES 결측치 제거 후 데이터 크기:", df_smi.shape)
# Out:
# SMILES 결측치 제거 후 데이터 크기: (9815, 28)

# %%
# 2. 분석 대상 실험 조건 필터링 (In Vivo 실험 및 Rat/Mouse만 선별)
# 데이터 수가 적었던 Hamster 데이터는 버리고 Rat과 Mouse만 선별함
df_filtered = df_smi[
    (df_smi["Data_Type"] == "In Vivo") & (df_smi["Species"].isin(["Rat", "Mouse"]))
].copy()
df_filtered
# Out:
#          Record_ID Data_Type Formulation_ID             Formulation_Name  \
# 2      cancer_3383   In Vivo            NaN                   Acronycine
# 3      cancer_3383   In Vivo            NaN                   Acronycine
# 4      cancer_3382   In Vivo            NaN                   Acronycine
# 5      cancer_3382   In Vivo            NaN                   Acronycine
# 6      cancer_3381   In Vivo            NaN                   Acronycine
# ...            ...       ...            ...                          ...
# 10303  cancer_7008   In Vivo            NaN                    Tenofovir
# 10304  cancer_7009   In Vivo            NaN                    Tenofovir
# 10308   cancer_483   In Vivo            NaN       N-Methylacetoacetamide
# 10309   cancer_482   In Vivo            NaN       N-Methylacetoacetamide
# 10313  cancer_1386   In Vivo            NaN  4-Methylcyclohexanemethanol
#
#                      Chemical_Name        CASRN         DTXSID  \
# 2                       Acronycine    7008-42-6  DTXSID0020026
# 3                       Acronycine    7008-42-6  DTXSID0020026
# 4                       Acronycine    7008-42-6  DTXSID0020026
# 5                       Acronycine    7008-42-6  DTXSID0020026
# 6                       Acronycine    7008-42-6  DTXSID0020026
# ...                            ...          ...            ...
# 10303                    Tenofovir  147127-20-6  DTXSID9040132
# 10304                    Tenofovir  147127-20-6  DTXSID9040132
# 10308       N-Methylacetoacetamide   20306-75-6  DTXSID9040138
# 10309       N-Methylacetoacetamide   20306-75-6  DTXSID9040138
# 10313  4-Methylcyclohexanemethanol   34885-03-5  DTXSID9041813
#
#        Percent_Active_Ingredient   Mixture Species  ...  \
# 2                            NaN  Chemical     Rat  ...
# 3                            NaN  Chemical     Rat  ...
# 4                            NaN  Chemical   Mouse  ...
# 5                            NaN  Chemical   Mouse  ...
# 6                            NaN  Chemical   Mouse  ...
# ...                          ...       ...     ...  ...
# 10303                        NaN  Chemical   Mouse  ...
# 10304                        NaN  Chemical   Mouse  ...
# 10308                        NaN  Chemical   Mouse  ...
# 10309                        NaN  Chemical   Mouse  ...
# 10313                        NaN  Chemical     Rat  ...
#
#                                          Endpoint               Response  \
# 2                                        Top dose                     15
# 3      Level of evidence of carcinogenic activity         Clear evidence
# 4                                        Top dose                     25
# 5      Level of evidence of carcinogenic activity  Inadequate experiment
# 6                                        Top dose                     25
# ...                                           ...                    ...
# 10303                                Micronucleus               Negative
# 10304                                Micronucleus               Positive
# 10308                                 Comet assay               Negative
# 10309                                Micronucleus               Negative
# 10313                                Micronucleus               Negative
#
#       Response_Unit Reference  \
# 2         mg/kg/day    TR-049
# 3          Unitless    TR-049
# 4         mg/kg/day    TR-049
# 5          Unitless    TR-049
# 6         mg/kg/day    TR-049
# ...             ...       ...
# 10303      Unitless       NaN
# 10304      Unitless       NaN
# 10308      Unitless       NaN
# 10309      Unitless       NaN
# 10313      Unitless       NaN
#
#                                                      URL  \
# 2      https://ntp.niehs.nih.gov/publications/reports...
# 3      https://ntp.niehs.nih.gov/publications/reports...
# 4      https://ntp.niehs.nih.gov/publications/reports...
# 5      https://ntp.niehs.nih.gov/publications/reports...
# 6      https://ntp.niehs.nih.gov/publications/reports...
# ...                                                  ...
# 10303  https://cebs.niehs.nih.gov/cebs/test_article/1...
# 10304  https://cebs.niehs.nih.gov/cebs/test_article/1...
# 10308  https://cebs.niehs.nih.gov/cebs/test_article/2...
# 10309  https://cebs.niehs.nih.gov/cebs/test_article/2...
# 10313  https://cebs.niehs.nih.gov/cebs/test_article/3...
#
#                                                   SMILES  \
# 2      COC1=CC2=C(C=CC(C)(C)O2)C2=C1C(=O)C1=C(C=CC=C1...
# 3      COC1=CC2=C(C=CC(C)(C)O2)C2=C1C(=O)C1=C(C=CC=C1...
# 4      COC1=CC2=C(C=CC(C)(C)O2)C2=C1C(=O)C1=C(C=CC=C1...
# 5      COC1=CC2=C(C=CC(C)(C)O2)C2=C1C(=O)C1=C(C=CC=C1...
# 6      COC1=CC2=C(C=CC(C)(C)O2)C2=C1C(=O)C1=C(C=CC=C1...
# ...                                                  ...
# 10303             C[C@H](CN1C=NC2=C1N=CN=C2N)OCP(O)(O)=O
# 10304             C[C@H](CN1C=NC2=C1N=CN=C2N)OCP(O)(O)=O
# 10308                                     CNC(=O)CC(C)=O
# 10309                                     CNC(=O)CC(C)=O
# 10313                                      CC1CCC(CO)CC1
#
#                     Preferred_Name  \
# 2                       Acronycine
# 3                       Acronycine
# 4                       Acronycine
# 5                       Acronycine
# 6                       Acronycine
# ...                            ...
# 10303                    Tenofovir
# 10304                    Tenofovir
# 10308       N-Methylacetoacetamide
# 10309       N-Methylacetoacetamide
# 10313  4-Methylcyclohexanemethanol
#
#                                                 Synonyms  \
# 2      7008-42-6|Acronycine|3,12-Dihydro-6-methoxy-3,...
# 3      7008-42-6|Acronycine|3,12-Dihydro-6-methoxy-3,...
# 4      7008-42-6|Acronycine|3,12-Dihydro-6-methoxy-3,...
# 5      7008-42-6|Acronycine|3,12-Dihydro-6-methoxy-3,...
# 6      7008-42-6|Acronycine|3,12-Dihydro-6-methoxy-3,...
# ...                                                  ...
# 10303  147127-20-6|Tenofovir|(((1R)-2-(6-Amino-9H-pur...
# 10304  147127-20-6|Tenofovir|(((1R)-2-(6-Amino-9H-pur...
# 10308  20306-75-6|N-Methylacetoacetamide|Acetoacet-mo...
# 10309  20306-75-6|N-Methylacetoacetamide|Acetoacet-mo...
# 10313  34885-03-5|4-Methylcyclohexanemethanol|Cyclohe...
#
#                                              URL_CompTox  \
# 2      https://comptox.epa.gov/dashboard/chemical/det...
# 3      https://comptox.epa.gov/dashboard/chemical/det...
# 4      https://comptox.epa.gov/dashboard/chemical/det...
# 5      https://comptox.epa.gov/dashboard/chemical/det...
# 6      https://comptox.epa.gov/dashboard/chemical/det...
# ...                                                  ...
# 10303  https://comptox.epa.gov/dashboard/chemical/det...
# 10304  https://comptox.epa.gov/dashboard/chemical/det...
# 10308  https://comptox.epa.gov/dashboard/chemical/det...
# 10309  https://comptox.epa.gov/dashboard/chemical/det...
# 10313  https://comptox.epa.gov/dashboard/chemical/det...
#
#                                               URL_CEBS
# 2      https://doi.org/10.22427/NTP-DATA-DTXSID0020026
# 3      https://doi.org/10.22427/NTP-DATA-DTXSID0020026
# 4      https://doi.org/10.22427/NTP-DATA-DTXSID0020026
# 5      https://doi.org/10.22427/NTP-DATA-DTXSID0020026
# 6      https://doi.org/10.22427/NTP-DATA-DTXSID0020026
# ...                                                ...
# 10303  https://doi.org/10.22427/NTP-DATA-DTXSID9040132
# 10304  https://doi.org/10.22427/NTP-DATA-DTXSID9040132
# 10308  https://doi.org/10.22427/NTP-DATA-DTXSID9040138
# 10309  https://doi.org/10.22427/NTP-DATA-DTXSID9040138
# 10313  https://doi.org/10.22427/NTP-DATA-DTXSID9041813
#
# [5863 rows x 28 columns]

# %%
# 3. Response 문형을 이진 라벨(0, 1)로 변환
# 조금이라고 반응이 있으면 위험하다고 판단하기 때문에 Some evidence 도 1로 치환함
label_map = {"Clear evidence": 1, "Some evidence": 1, "No evidence": 0}
df_filtered = df_filtered[df_filtered["Response"].isin(label_map.keys())].copy()
df_filtered["label"] = df_filtered["Response"].map(label_map)

# 4. 모델 학습용 기본 피처 생성 (종, 성별 이진화)
#Is_Rat=1 이면 Rat, Is_Rat=0이면 Mouse
#Is_Male=1 이면 수컷, Is_Male=0이면 암컷
df_filtered["Is_Rat"] = (df_filtered["Species"] == "Rat").astype(int)
df_filtered["Is_Male"] = (df_filtered["Sex"] == "Male").astype(int)

print("필터링 및 이진화 후 데이터 크기:", df_filtered.shape)
df_filtered
# Out:
# 필터링 및 이진화 후 데이터 크기: (1757, 31)
#          Record_ID Data_Type Formulation_ID      Formulation_Name  \
# 3      cancer_3383   In Vivo            NaN            Acronycine
# 9      cancer_3380   In Vivo            NaN            Acronycine
# 21     cancer_6845   In Vivo            NaN        Benzyl acetate
# 23     cancer_6844   In Vivo            NaN        Benzyl Acetate
# 24     cancer_6840   In Vivo            NaN        Benzyl acetate
# ...            ...       ...            ...                   ...
# 10211  cancer_5373   In Vivo            NaN   alpha-Methylstyrene
# 10214  cancer_5370   In Vivo            NaN   alpha-Methylstyrene
# 10219  cancer_5369   In Vivo            NaN   alpha-Methylstyrene
# 10289  cancer_3034   In Vivo            NaN  Allyl Glycidyl Ether
# 10295  cancer_3036   In Vivo            NaN  Allyl Glycidyl Ether
#
#               Chemical_Name      CASRN         DTXSID  \
# 3                Acronycine  7008-42-6  DTXSID0020026
# 9                Acronycine  7008-42-6  DTXSID0020026
# 21           Benzyl acetate   140-11-4  DTXSID0020151
# 23           Benzyl acetate   140-11-4  DTXSID0020151
# 24           Benzyl acetate   140-11-4  DTXSID0020151
# ...                     ...        ...            ...
# 10211   alpha-Methylstyrene    98-83-9  DTXSID9025661
# 10214   alpha-Methylstyrene    98-83-9  DTXSID9025661
# 10219   alpha-Methylstyrene    98-83-9  DTXSID9025661
# 10289  Allyl glycidyl ether   106-92-3  DTXSID9039232
# 10295  Allyl glycidyl ether   106-92-3  DTXSID9039232
#
#        Percent_Active_Ingredient   Mixture Species  ... Reference  \
# 3                            NaN  Chemical     Rat  ...    TR-049
# 9                            NaN  Chemical     Rat  ...    TR-049
# 21                           NaN  Chemical     Rat  ...    TR-250
# 23                           NaN  Chemical     Rat  ...    TR-431
# 24                           NaN  Chemical   Mouse  ...    TR-250
# ...                          ...       ...     ...  ...       ...
# 10211                        NaN  Chemical     Rat  ...    TR-543
# 10214                        NaN  Chemical     Rat  ...    TR-543
# 10219                        NaN  Chemical   Mouse  ...    TR-543
# 10289                        NaN  Chemical   Mouse  ...    TR-376
# 10295                        NaN  Chemical     Rat  ...    TR-376
#
#                                                      URL  \
# 3      https://ntp.niehs.nih.gov/publications/reports...
# 9      https://ntp.niehs.nih.gov/publications/reports...
# 21     https://ntp.niehs.nih.gov/publications/reports...
# 23     https://ntp.niehs.nih.gov/publications/reports...
# 24     https://ntp.niehs.nih.gov/publications/reports...
# ...                                                  ...
# 10211  https://ntp.niehs.nih.gov/publications/reports...
# 10214  https://ntp.niehs.nih.gov/publications/reports...
# 10219  https://ntp.niehs.nih.gov/publications/reports...
# 10289  https://ntp.niehs.nih.gov/publications/reports...
# 10295  https://ntp.niehs.nih.gov/publications/reports...
#
#                                                   SMILES  \
# 3      COC1=CC2=C(C=CC(C)(C)O2)C2=C1C(=O)C1=C(C=CC=C1...
# 9      COC1=CC2=C(C=CC(C)(C)O2)C2=C1C(=O)C1=C(C=CC=C1...
# 21                                   CC(=O)OCC1=CC=CC=C1
# 23                                   CC(=O)OCC1=CC=CC=C1
# 24                                   CC(=O)OCC1=CC=CC=C1
# ...                                                  ...
# 10211                                  CC(=C)C1=CC=CC=C1
# 10214                                  CC(=C)C1=CC=CC=C1
# 10219                                  CC(=C)C1=CC=CC=C1
# 10289                                        C=CCOCC1CO1
# 10295                                        C=CCOCC1CO1
#
#              Preferred_Name  \
# 3                Acronycine
# 9                Acronycine
# 21           Benzyl acetate
# 23           Benzyl acetate
# 24           Benzyl acetate
# ...                     ...
# 10211   alpha-Methylstyrene
# 10214   alpha-Methylstyrene
# 10219   alpha-Methylstyrene
# 10289  Allyl glycidyl ether
# 10295  Allyl glycidyl ether
#
#                                                 Synonyms  \
# 3      7008-42-6|Acronycine|3,12-Dihydro-6-methoxy-3,...
# 9      7008-42-6|Acronycine|3,12-Dihydro-6-methoxy-3,...
# 21     140-11-4|Benzyl acetate|(Acetoxymethyl)benzene...
# 23     140-11-4|Benzyl acetate|(Acetoxymethyl)benzene...
# 24     140-11-4|Benzyl acetate|(Acetoxymethyl)benzene...
# ...                                                  ...
# 10211  98-83-9|alpha-Methylstyrene|(1-Methylethenyl)b...
# 10214  98-83-9|alpha-Methylstyrene|(1-Methylethenyl)b...
# 10219  98-83-9|alpha-Methylstyrene|(1-Methylethenyl)b...
# 10289  106-92-3|Allyl glycidyl ether|(.+-.)-Allyl gly...
# 10295  106-92-3|Allyl glycidyl ether|(.+-.)-Allyl gly...
#
#                                              URL_CompTox  \
# 3      https://comptox.epa.gov/dashboard/chemical/det...
# 9      https://comptox.epa.gov/dashboard/chemical/det...
# 21     https://comptox.epa.gov/dashboard/chemical/det...
# 23     https://comptox.epa.gov/dashboard/chemical/det...
# 24     https://comptox.epa.gov/dashboard/chemical/det...
# ...                                                  ...
# 10211  https://comptox.epa.gov/dashboard/chemical/det...
# 10214  https://comptox.epa.gov/dashboard/chemical/det...
# 10219  https://comptox.epa.gov/dashboard/chemical/det...
# 10289  https://comptox.epa.gov/dashboard/chemical/det...
# 10295  https://comptox.epa.gov/dashboard/chemical/det...
#
#                                               URL_CEBS label Is_Rat Is_Male
# 3      https://doi.org/10.22427/NTP-DATA-DTXSID0020026     1      1       1
# 9      https://doi.org/10.22427/NTP-DATA-DTXSID0020026     1      1       0
# 21     https://doi.org/10.22427/NTP-DATA-DTXSID0020151     0      1       0
# 23     https://doi.org/10.22427/NTP-DATA-DTXSID0020151     0      1       0
# 24     https://doi.org/10.22427/NTP-DATA-DTXSID0020151     1      0       1
# ...                                                ...   ...    ...     ...
# 10211  https://doi.org/10.22427/NTP-DATA-DTXSID9025661     0      1       0
# 10214  https://doi.org/10.22427/NTP-DATA-DTXSID9025661     1      1       1
# 10219  https://doi.org/10.22427/NTP-DATA-DTXSID9025661     1      0       0
# 10289  https://doi.org/10.22427/NTP-DATA-DTXSID9039232     1      0       1
# 10295  https://doi.org/10.22427/NTP-DATA-DTXSID9039232     0      1       0
#
# [1757 rows x 31 columns]

# %%
# 중복 조건(SMILES, 종, 성별)을 묶고 상충 데이터는 max() 처리
df_clean = (
    df_filtered.groupby(["SMILES", "Is_Rat", "Is_Male"]) #SMILES, Is_Rat, Is_Male 3가지가 완벽하게 같은 것을 하나로 묶음
    .agg({"Chemical_Name": "first", "label": "max"}) #이 떄 가장 처음으로 나오는 화학 물질 이름을 따라가며 발암성으로 구분된 것이 하나라도 있는 경우 label을 1로 지정하겠다는 뜻
    .reset_index()
)

df_clean = df_clean[["Chemical_Name", "SMILES", "Is_Rat", "Is_Male", "label"]]

# 결과 확인하기
print("최종 정제 및 중복 제거 완료 후 데이터 크기:", df_clean.shape)
df_clean
# Out:
# 최종 정제 및 중복 제거 완료 후 데이터 크기: (1682, 5)
#                      Chemical_Name                                   SMILES  \
# 0                   Divinylbenzene  *C=C.C=CC1=CC=CC=C1 |c:6,8,t:4,m:0:8.6|
# 1                   Divinylbenzene  *C=C.C=CC1=CC=CC=C1 |c:6,8,t:4,m:0:8.6|
# 2                        Bromoform                                BrC(Br)Br
# 3                        Bromoform                                BrC(Br)Br
# 4                        Bromoform                                BrC(Br)Br
# ...                            ...                                      ...
# 1677  Lead dimethyldithiocarbamate     [Pb++].CN(C)C([S-])=S.CN(C)C([S-])=S
# 1678  Lead dimethyldithiocarbamate     [Pb++].CN(C)C([S-])=S.CN(C)C([S-])=S
# 1679                         Ziram     [Zn++].CN(C)C([S-])=S.CN(C)C([S-])=S
# 1680                         Ziram     [Zn++].CN(C)C([S-])=S.CN(C)C([S-])=S
# 1681                         Ziram     [Zn++].CN(C)C([S-])=S.CN(C)C([S-])=S
#
#       Is_Rat  Is_Male  label
# 0          0        1      0
# 1          1        0      0
# 2          0        0      0
# 3          0        1      0
# 4          1        0      1
# ...      ...      ...    ...
# 1677       1        0      0
# 1678       1        1      0
# 1679       0        1      0
# 1680       1        0      0
# 1681       1        1      1
#
# [1682 rows x 5 columns]

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\ds\miniconda3\envs\rdkit_env\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\ds\miniconda3\envs\rdkit_env\lib\site-packages (from seaborn) (2.2.5)
# Requirement already satisfied: pandas>=1.2 in c:\users\ds\miniconda3\envs\rdkit_env\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\ds\miniconda3\envs\rdkit_env\lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ds\miniconda3\envs\rdkit_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ds\miniconda3\envs\rdkit_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ds\miniconda3\envs\rdkit_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ds\miniconda3\envs\rdkit_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ds\miniconda3\envs\rdkit_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\ds\miniconda3\envs\rdkit_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\ds\miniconda3\envs\rdkit_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ds\miniconda3\envs\rdkit_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ds\miniconda3\envs\rdkit_env\lib\site-packages (from pandas>=1.2->seaborn) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ds\miniconda3\envs\rdkit_env\lib\site-packages (from pandas>=1.2->seaborn) (2026.1)
# Requirement already satisfied: six>=1.5 in c:\users\ds\miniconda3\envs\rdkit_env\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# ----------------------------------------------------------------------
# 🎨 [1번, 2번] 순수 분포 그래프 전용 색상 커스텀
# ----------------------------------------------------------------------
sex_total_color = "#000080"       # 1번 그래프: 전체 성별 바 색상
species_total_color = "#000080"   # 2번 그래프: 전체 동물 종 바 색상

# 그래프 스타일 및 한글 설정
sns.set_theme(style="whitegrid")
plt.rcParams['font.family'] = 'Malgun Gothic' # 맥북이면 'AppleGothic'
plt.rcParams['axes.unicode_minus'] = False

# 가로로 2개의 그래프 배치 (1번과 2번 한 번에)
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# [왼쪽] 1. 전체 실험 동물 성별 분포
sns.countplot(x='Is_Male', data=df_clean, ax=axes[0], color=sex_total_color)
axes[0].set_title('1. 전체 실험 동물 성별 분포 (Sex Distribution)', fontsize=14, fontweight='bold')
axes[0].set_xlabel('성별 (Sex)', fontsize=12)
axes[0].set_ylabel('화합물 데이터 개수 (Count)', fontsize=12)
axes[0].set_xticklabels(['암컷 (Female)', '수컷 (Male)'])

# [오른쪽] 2. 전체 실험 동물 종 분포
sns.countplot(x='Is_Rat', data=df_clean, ax=axes[1], color=species_total_color)
axes[1].set_title('2. 전체 실험 동물 종(Species) 분포 (Species Distribution)', fontsize=14, fontweight='bold')
axes[1].set_xlabel('동물 종 (Species)', fontsize=12)
axes[1].set_ylabel('화합물 데이터 개수 (Count)', fontsize=12)
axes[1].set_xticklabels(['마우스 (Mouse)', '랫드 (Rat)'])

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# ----------------------------------------------------------------------
# 🎨 [3번, 4번] 라벨 분류 그래프 전용 색상 커스텀
# ----------------------------------------------------------------------
label_0_color = "#0000FF"  # 0(비발암성) 바 색상
label_1_color = "#FF0000"  # 1(발암성) 바 색상

# 그래프 스타일 및 한글 설정
sns.set_theme(style="whitegrid")
plt.rcParams['font.family'] = 'Malgun Gothic' # 맥북이면 'AppleGothic'
plt.rcParams['axes.unicode_minus'] = False

# 가로로 2개의 그래프 배치 (3번과 4번 한 번에)
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# [왼쪽] 3. 성별에 따른 발암성(label) 분포
sns.countplot(x='Is_Male', hue='label', data=df_clean, ax=axes[0], 
              palette={0: label_0_color, 1: label_1_color})
axes[0].set_title('3. 성별에 따른 발암성(label) 분포', fontsize=14, fontweight='bold')
axes[0].set_xlabel('성별 (Sex)', fontsize=12)
axes[0].set_ylabel('화합물 데이터 개수 (Count)', fontsize=12)
axes[0].set_xticklabels(['암컷 (Female)', '수컷 (Male)'])
axes[0].legend(title='발암성 유무', labels=['0: 비발암성', '1: 발암성'])

# [오른쪽] 4. 동물 종에 따른 발암성(label) 분포
sns.countplot(x='Is_Rat', hue='label', data=df_clean, ax=axes[1], 
              palette={0: label_0_color, 1: label_1_color})
axes[1].set_title('4. 동물 종에 따른 발암성(label) 분포', fontsize=14, fontweight='bold')
axes[1].set_xlabel('동물 종 (Species)', fontsize=12)
axes[1].set_ylabel('화합물 데이터 개수 (Count)', fontsize=12)
axes[1].set_xticklabels(['마우스 (Mouse)', '랫드 (Rat)'])
axes[1].legend(title='발암성 유무', labels=['0: 비발암성', '1: 발암성'])

plt.tight_layout()
plt.show()

# %%
from rdkit import Chem

# SMILES 코드를 표준(Canonical) 형태로 변환하는 함수 정의
def fix_smiles(smiles_string):
    try:
        # 텍스트를 RDKit 분자 객체로 변환
        mol = Chem.MolFromSmiles(smiles_string)
        if mol is not None:
            # 다시 텍스트로 바꾸면 RDKit이 무조건 '표준 표기법'으로 바꿔줌
            return Chem.MolToSmiles(mol, canonical=True)
        else:
            return None # 구조가 깨진 이상한 글자면 None 반환
    except:
        return None

# 기존 df_clean의 SMILES를 깨끗하게 정리해서 새로운 컬럼으로 만들기
df_clean["Canonical_SMILES"] = df_clean["SMILES"].apply(fix_smiles)

# 구조가 깨져서 변환에 실패한 데이터(None)가 있는지 확인하고 제거
before_count = df_clean.shape[0]
df_clean = df_clean.dropna(subset=["Canonical_SMILES"]).copy()
after_count = df_clean.shape[0]

# 기존 SMILES 컬럼을 정형화된 컬럼으로 교체하고 정리
df_clean["SMILES"] = df_clean["Canonical_SMILES"]
df_clean = df_clean.drop(columns=["Canonical_SMILES"])

# 결과 확인하기
print("SMILES 코드 정리 완료!")
print("구조 에러로 제거된 물질 개수:", before_count - after_count)
print("최종 정제된 데이터 크기:", df_clean.shape)

df_clean
# Out:
# SMILES 코드 정리 완료!
# 구조 에러로 제거된 물질 개수: 0
# 최종 정제된 데이터 크기: (1682, 5)
#                      Chemical_Name                                SMILES  \
# 0                   Divinylbenzene                      *C=C.C=Cc1ccccc1
# 1                   Divinylbenzene                      *C=C.C=Cc1ccccc1
# 2                        Bromoform                             BrC(Br)Br
# 3                        Bromoform                             BrC(Br)Br
# 4                        Bromoform                             BrC(Br)Br
# ...                            ...                                   ...
# 1677  Lead dimethyldithiocarbamate  CN(C)C(=S)[S-].CN(C)C(=S)[S-].[Pb+2]
# 1678  Lead dimethyldithiocarbamate  CN(C)C(=S)[S-].CN(C)C(=S)[S-].[Pb+2]
# 1679                         Ziram  CN(C)C(=S)[S-].CN(C)C(=S)[S-].[Zn+2]
# 1680                         Ziram  CN(C)C(=S)[S-].CN(C)C(=S)[S-].[Zn+2]
# 1681                         Ziram  CN(C)C(=S)[S-].CN(C)C(=S)[S-].[Zn+2]
#
#       Is_Rat  Is_Male  label
# 0          0        1      0
# 1          1        0      0
# 2          0        0      0
# 3          0        1      0
# 4          1        0      1
# ...      ...      ...    ...
# 1677       1        0      0
# 1678       1        1      0
# 1679       0        1      0
# 1680       1        0      0
# 1681       1        1      1
#
# [1682 rows x 5 columns]

# %%
df_clean.to_csv('cancer_cleaned.csv')

# %%
from rdkit import Chem
from rdkit.Chem import Descriptors
from rdkit.Chem import AllChem

# 분자 성질(2D Descriptor)을 계산해서 리스트로 반환하는 함수
def get_features(smiles_string):
    try:
        # SMILES 텍스트를 RDKit이 이해하는 분자 객체로 변환
        mol = Chem.MolFromSmiles(smiles_string)
        if mol is None:
            return None
        
        # 가산점과 모델 성능을 위해 꼭 필요한 주요 물리화학적 성질 4가지 계산
        mol_wt = Descriptors.MolWt(mol)          # 분자량 (덩치)
        log_p = Descriptors.MolLogP(mol)         # 지용성 (기름에 녹는 정도)
        h_donors = Descriptors.NumHDonors(mol)    # 수소 결합 공여자 수
        h_acceptors = Descriptors.NumHAcceptors(mol) # 수소 결합 수용체 수
        
        return [mol_wt, log_p, h_donors, h_acceptors]
    except:
        return None

print("RDKit 함수 준비 완료!")
# Out:
# RDKit 함수 준비 완료!

# %%
# 모든 화합물의 2D Descriptor 계산 진행
desc_list = df_clean["SMILES"].apply(get_features)

# 계산된 결과를 알아보기 쉽게 데이터프레임로 변환
desc_cols = ["MolWt", "LogP", "NumHDonors", "NumHAcceptors"]
df_desc = pd.DataFrame(desc_list.tolist(), columns=desc_cols)

# 결과 확인하기 (상위 5개 데이터 미리보기)
print("계산된 Descriptor 표의 크기:", df_desc.shape)
df_desc.head()
# Out:
# 계산된 Descriptor 표의 크기: (1682, 4)
#      MolWt    LogP  NumHDonors  NumHAcceptors
# 0  131.198  3.0088           0              0
# 1  131.198  3.0088           0              0
# 2  252.731  2.4547           0              0
# 3  252.731  2.4547           0              0
# 4  252.731  2.4547           0              0

# %%
from rdkit import Chem
import warnings
warnings.filterwarnings('ignore')
from rdkit.Chem import AllChem

# 1. Morgan Fingerprint 계산 함수 정의 (설명하기 쉽게 32비트 크기로 설정)
def get_fingerprint_32(smiles_string):
    try:
        mol = Chem.MolFromSmiles(smiles_string)
        if mol is None:
            return None
        
        # radius=2(화학적 환경 반경), nBits=32(지문 크기)로 설정
        fp = AllChem.GetMorganFingerprintAsBitVect(mol, radius=2, nBits=32)
        return list(fp) # 0과 1로 이루어진 32개 비트 리스트 반환
    except:
        return None

# 2. 모든 화합물의 지문 계산 진행 (약 5~10초 소요)
fp_list = df_clean["SMILES"].apply(get_fingerprint_32)

# 3. 계산된 지문을 알아보기 쉽게 표(DataFrame)로 변환
fp_cols = ["FP_" + str(i) for i in range(32)]
df_fp = pd.DataFrame(fp_list.tolist(), columns=fp_cols)

# 4. df_clean에 계산된 성질(df_desc)과 지문(df_fp) 컬럼들을 통째로 추가하기
# 먼저 2D Descriptor 4가지 추가
for col in df_desc.columns:
    df_clean[col] = df_desc[col]

# 이어서 32비트 핑거프린트 32개 추가
for col in df_fp.columns:
    df_clean[col] = df_fp[col]

# 5. 최종 정제된 전체 데이터를 교수님 지정 명세서 규칙에 맞게 저장 (인덱스 제외)
df_clean.to_csv("cancer_descriptors.csv", index=False)

# 6. 최종 결과물 완벽 검증 및 출력
print("🎉 2D Descriptor + 32비트 핑거프린트 통합 완료!")
print("최종 df_clean의 크기 (행, 열):", df_clean.shape)
print("\n--- 생성된 최종 컬럼 목록 ---")
print(df_clean.columns.tolist())
# Out:
# 🎉 2D Descriptor + 32비트 핑거프린트 통합 완료!
# 최종 df_clean의 크기 (행, 열): (1682, 41)
#
# --- 생성된 최종 컬럼 목록 ---
# ['Chemical_Name', 'SMILES', 'Is_Rat', 'Is_Male', 'label', 'MolWt', 'LogP', 'NumHDonors', 'NumHAcceptors', 'FP_0', 'FP_1', 'FP_2', 'FP_3', 'FP_4', 'FP_5', 'FP_6', 'FP_7', 'FP_8', 'FP_9', 'FP_10', 'FP_11', 'FP_12', 'FP_13', 'FP_14', 'FP_15', 'FP_16', 'FP_17', 'FP_18', 'FP_19', 'FP_20', 'FP_21', 'FP_22', 'FP_23', 'FP_24', 'FP_25', 'FP_26', 'FP_27', 'FP_28', 'FP_29', 'FP_30', 'FP_31']
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:12] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# ...
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator
# [17:29:13] DEPRECATION WARNING: please use MorganGenerator

# %% [markdown]
# ### 최종 데이터의 라벨 밸런스(비율) 확인하기

# %%
import pandas as pd

# 1. 발암성(label)별 빈도수(Count)와 비율(Percentage) 계산
label_counts = df_clean['label'].value_counts()
label_percentages = df_clean['label'].value_counts(normalize=True) * 100

# 2. 교수님 제출용 깔끔한 요약 표(DataFrame) 생성
summary_table = pd.DataFrame({
    '화합물 개수 (Count)': label_counts,
    '비율 (Percentage, %)': label_percentages
})

# 3. 인덱스 이름을 직관적인 학술 용어로 변경
summary_table.index = summary_table.index.map({0: '비발암성 물질 (No Evidence)', 1: '발암성 물질 (Evidence 있음)'})

# 4. 소수점 둘째 자리까지 이쁘게 출력되도록 포맷팅 및 총합(Total) 행 추가
summary_table['비율 (Percentage, %)'] = summary_table['비율 (Percentage, %)'].map('{:.2f}%'.format)

# 총합 행 계산을 위해 임시로 숫자로 더한 뒤 붙이기
total_row = pd.DataFrame(
    [['총 화합물 개수: ' + str(label_counts.sum()), '100.00%']], 
    columns=['화합물 개수 (Count)', '비율 (Percentage, %)'], 
    index=['전체 데이터셋 (Total)']
)
final_summary = pd.concat([summary_table, total_row])

# 최종 표 출력
print("=== [Template 1] 최종 데이터셋 발암성 라벨 분포 현황 ===")
display(final_summary)
# Out:
# === [Template 1] 최종 데이터셋 발암성 라벨 분포 현황 ===
#                        화합물 개수 (Count) 비율 (Percentage, %)
# 비발암성 물질 (No Evidence)             974             57.91%
# 발암성 물질 (Evidence 있음)              708             42.09%
# 전체 데이터셋 (Total)        총 화합물 개수: 1682            100.00%

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# ----------------------------------------------------------------------
# 🎨 [1번, 2번] 순수 분포 그래프 전용 색상 커스텀
# ----------------------------------------------------------------------
sex_total_color = "#000080"       # 1번 그래프: 전체 성별 바 색상
species_total_color = "#000080"   # 2번 그래프: 전체 동물 종 바 색상

# 그래프 스타일 및 한글 설정
sns.set_theme(style="whitegrid")
plt.rcParams['font.family'] = 'Malgun Gothic' # 맥북이면 'AppleGothic'
plt.rcParams['axes.unicode_minus'] = False

# 가로로 2개의 그래프 배치 (1번과 2번 한 번에)
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# [왼쪽] 1. 전체 실험 동물 성별 분포
sns.countplot(x='Is_Male', data=df_clean, ax=axes[0], color=sex_total_color)
axes[0].set_title('1. 전체 실험 동물 성별 분포 (Sex Distribution)', fontsize=14, fontweight='bold')
axes[0].set_xlabel('성별 (Sex)', fontsize=12)
axes[0].set_ylabel('화합물 데이터 개수 (Count)', fontsize=12)
axes[0].set_xticklabels(['암컷 (Female)', '수컷 (Male)'])

# [오른쪽] 2. 전체 실험 동물 종 분포
sns.countplot(x='Is_Rat', data=df_clean, ax=axes[1], color=species_total_color)
axes[1].set_title('2. 전체 실험 동물 종(Species) 분포 (Species Distribution)', fontsize=14, fontweight='bold')
axes[1].set_xlabel('동물 종 (Species)', fontsize=12)
axes[1].set_ylabel('화합물 데이터 개수 (Count)', fontsize=12)
axes[1].set_xticklabels(['마우스 (Mouse)', '랫드 (Rat)'])

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# ----------------------------------------------------------------------
# 🎨 [3번, 4번] 라벨 분류 그래프 전용 색상 커스텀
# ----------------------------------------------------------------------
label_0_color = "#0000FF"  # 0(비발암성) 바 색상
label_1_color = "#FF0000"  # 1(발암성) 바 색상

# 그래프 스타일 및 한글 설정
sns.set_theme(style="whitegrid")
plt.rcParams['font.family'] = 'Malgun Gothic' # 맥북이면 'AppleGothic'
plt.rcParams['axes.unicode_minus'] = False

# 가로로 2개의 그래프 배치 (3번과 4번 한 번에)
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# [왼쪽] 3. 성별에 따른 발암성(label) 분포
sns.countplot(x='Is_Male', hue='label', data=df_clean, ax=axes[0], 
              palette={0: label_0_color, 1: label_1_color})
axes[0].set_title('3. 성별에 따른 발암성(label) 분포', fontsize=14, fontweight='bold')
axes[0].set_xlabel('성별 (Sex)', fontsize=12)
axes[0].set_ylabel('화합물 데이터 개수 (Count)', fontsize=12)
axes[0].set_xticklabels(['암컷 (Female)', '수컷 (Male)'])
axes[0].legend(title='발암성 유무', labels=['0: 비발암성', '1: 발암성'])

# [오른쪽] 4. 동물 종에 따른 발암성(label) 분포
sns.countplot(x='Is_Rat', hue='label', data=df_clean, ax=axes[1], 
              palette={0: label_0_color, 1: label_1_color})
axes[1].set_title('4. 동물 종에 따른 발암성(label) 분포', fontsize=14, fontweight='bold')
axes[1].set_xlabel('동물 종 (Species)', fontsize=12)
axes[1].set_ylabel('화합물 데이터 개수 (Count)', fontsize=12)
axes[1].set_xticklabels(['마우스 (Mouse)', '랫드 (Rat)'])
axes[1].legend(title='발암성 유무', labels=['0: 비발암성', '1: 발암성'])

plt.tight_layout()
plt.show()

# %%
import pandas as pd

# 1. 발암성(label)별 빈도수(Count)와 비율(Percentage) 계산
label_counts = df_clean['label'].value_counts()
label_percentages = df_clean['label'].value_counts(normalize=True) * 100

# 2. 교수님 제출용 깔끔한 요약 표(DataFrame) 생성
summary_table = pd.DataFrame({
    '화합물 개수 (Count)': label_counts,
    '비율 (Percentage, %)': label_percentages
})

# 3. 인덱스 이름을 직관적인 학술 용어로 변경
summary_table.index = summary_table.index.map({0: '비발암성 물질 (No Evidence)', 1: '발암성 물질 (Evidence 있음)'})

# 4. 소수점 둘째 자리까지 이쁘게 출력되도록 포맷팅 및 총합(Total) 행 추가
summary_table['비율 (Percentage, %)'] = summary_table['비율 (Percentage, %)'].map('{:.2f}%'.format)

# 총합 행 계산을 위해 임시로 숫자로 더한 뒤 붙이기
total_row = pd.DataFrame(
    [['총 화합물 개수: ' + str(label_counts.sum()), '100.00%']], 
    columns=['화합물 개수 (Count)', '비율 (Percentage, %)'], 
    index=['전체 데이터셋 (Total)']
)
final_summary = pd.concat([summary_table, total_row])

# 최종 표 출력
print("=== [Template 1] 최종 데이터셋 발암성 라벨 분포 현황 ===")
display(final_summary)
# Out:
# === [Template 1] 최종 데이터셋 발암성 라벨 분포 현황 ===
#                        화합물 개수 (Count) 비율 (Percentage, %)
# 비발암성 물질 (No Evidence)             974             57.91%
# 발암성 물질 (Evidence 있음)              708             42.09%
# 전체 데이터셋 (Total)        총 화합물 개수: 1682            100.00%

# %%
import matplotlib.pyplot as plt

# 1. 🎨 파이 차트 전용 색상 커스텀 (원하는 색상 코드로 자유롭게 변경!)
color_non_cancer = "#87CEEB"
color_cancer = "#FFB6C1"

# 2. 한글 깨짐 방지 설정
plt.rcParams['font.family'] = 'Malgun Gothic' # 맥북이면 'AppleGothic'
plt.rcParams['axes.unicode_minus'] = False

# 3. 데이터 분포 계산 (라벨이 문자열이든 숫자든 상관없이 개수 집계)
label_counts = df_clean['label'].value_counts()

# 4. 딱 파이 차트 한 장만 이쁜 크기로 생성
plt.figure(figsize=(7, 7))

plt.pie(
    label_counts, 
    labels=['비발암성 (No Evidence)', '발암성 (Evidence 있음)'], 
    autopct='%1.2f%%',          # 소수점 둘째 자리까지 비율 표시
    startangle=90,              # 보기 좋게 12시 방향에서 시작
    colors=[color_non_cancer, color_cancer], # 우리가 지정한 예쁜 색상 적용
    textprops={'fontsize': 12, 'fontweight': 'bold'}, # 글자 크기와 굵기
    wedgeprops={'edgecolor': 'white', 'linewidth': 3, 'antialiased': True} # 조각 사이 흰색 테두리
)

# 그래프 제목 설정
plt.title('최종 데이터셋 발암성 물질 비율 현황 (%)', fontsize=15, fontweight='bold', pad=20)

plt.tight_layout()
plt.show()
